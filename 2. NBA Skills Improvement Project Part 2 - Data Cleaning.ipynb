# %% [markdown]
# ## NBA Skills Improvement Project Part 2 - Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd.set_option('display.max_columns', None)
pd.reset_option('display.max_rows')

# %%
shooting_df = pd.read_csv("C:/Users/kevin/Downloads/shooting stats 2014-2023.csv")

# %%
defensive_df = pd.read_csv("C:/Users/kevin/Downloads/defensive stats 2014-23.csv")

# %%
player_bios = pd.read_csv('C:/Users/kevin/Downloads/player bios 2014-2023.csv')

# %% [markdown]
# ### Cleaning the Shooting Data Set First

# %% [markdown]
# Normalizing the names to not include special characters.

# %%
shooting_df["Player"] = shooting_df["Player"].str.replace("*","", regex=False)
shooting_df["Player"] = shooting_df["Player"].str.replace("+","", regex=False)

# %%
shooting = pd.merge(shooting_df, player_bios, how='left', left_on='Player', right_on='DISPLAY_FIRST_LAST')

# %%
shooting = shooting[shooting['Player'] != 'Player']

# %% [markdown]
# Consolidating players down to one row if they played multiple seasons.

# %%
def single_year(df):
    if df["Tm"].nunique() == 1:
        return df  # Return the row if player only played for one team
    else:
        return df[df["Tm"] == "TOT"]

# %%
shooting = shooting.groupby(["Player", "Year"]).apply(single_year)

# %%
shooting.index = shooting.index.droplevel()
shooting.index = shooting.index.droplevel()

# %%
shooting[shooting['Player'] == 'Spencer Dinwiddie']
# Out:
#                  Player    Pos Age   Tm   G    MP   FG% Dist. 2P_FGA%  \
# 801   Spencer Dinwiddie     PG  21  DET  34   455  .302  14.9    .615
# 1444  Spencer Dinwiddie     PG  22  DET  12   159  .352   9.9    .815
# 2050  Spencer Dinwiddie     PG  23  BRK  59  1334  .444  13.6    .666
# 2695  Spencer Dinwiddie     PG  24  BRK  80  2306  .387  16.1    .483
# 3405  Spencer Dinwiddie     PG  25  BRK  68  1914  .442  14.4    .553
# 4135  Spencer Dinwiddie     PG  26  BRK  64  1994  .415  13.3    .608
# 4806  Spencer Dinwiddie     SG  27  BRK   3    64  .375  12.3    .563
# 5540  Spencer Dinwiddie     PG  28  TOT  67  1980  .416  15.6    .551
# 6366  Spencer Dinwiddie  SG-PG  29  TOT  79  2725  .438  15.7    .533
#
#      0-3_FGA% 3-10_FGA% 10-16_FGA% 16-3P_FGA% 3P_FGA% 2P_FG% 0-3_FG% 3-10_FG%  \
# 801      .219      .154       .112       .130    .385   .375    .459     .269
# 1444     .333      .185       .148       .130    .185   .409    .611     .100
# 2050     .295      .156       .132       .089    .334   .478    .584     .362
# 2695     .233      .122       .084       .045    .517   .452    .574     .324
# 3405     .281      .185       .064       .023    .447   .528    .648     .399
# 4135     .310      .191       .078       .028    .392   .485    .637     .354
# 4806     .313      .250       .000       .000    .438   .444    .600     .250
# 5540     .176      .237       .088       .050    .449   .479    .643     .402
# 6366     .186      .206       .092       .050    .467   .498    .646     .417
#
#      10-16_FG% 16-3P_FG% 3P_FG% 2P_FGast 3P_FGast Dunks_%FGA Dunks_#  \
# 801       .316      .409   .185     .128     .167       .006       1
# 1444      .375      .429   .100     .111     .000       .019       1
# 2050      .325      .556   .376     .229     .579       .023       7
# 2695      .371      .316   .326     .142     .596       .017      12
# 3405      .453      .316   .335     .165     .556       .021      15
# 4135      .263      .310   .308     .176     .496       .014      14
# 4806       NaN       NaN   .286     .500    1.000       .063       1
# 5540      .446      .324   .339     .201     .536       .007       3
# 6366      .423      .423   .369     .118     .602       .021      17
#
#      Corner_%3PA Corner_3P% Heaves_Att. Heaves_#  Year  PERSON_ID FIRST_NAME  \
# 801         .062       .250           2        0  2015   203915.0    Spencer
# 1444        .000        NaN           0        0  2016   203915.0    Spencer
# 2050        .188       .474           1        0  2017   203915.0    Spencer
# 2695        .081       .371           1        0  2018   203915.0    Spencer
# 3405        .168       .403           5        1  2019   203915.0    Spencer
# 4135        .130       .327           5        0  2020   203915.0    Spencer
# 4806        .143      1.000           0        0  2021   203915.0    Spencer
# 5540        .182       .367           1        0  2022   203915.0    Spencer
# 6366        .182       .506           1        0  2023   203915.0    Spencer
#
#       LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST DISPLAY_FI_LAST  \
# 801   Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 1444  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 2050  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 2695  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 3405  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 4135  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 4806  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 5540  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
# 6366  Dinwiddie  Spencer Dinwiddie       Dinwiddie, Spencer    S. Dinwiddie
#
#             PLAYER_SLUG            BIRTHDATE    SCHOOL COUNTRY  \
# 801   spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 1444  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 2050  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 2695  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 3405  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 4135  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 4806  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 5540  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
# 6366  spencer-dinwiddie  1993-04-06T00:00:00  Colorado     USA
#
#      LAST_AFFILIATION HEIGHT  WEIGHT  SEASON_EXP  JERSEY POSITION  \
# 801      Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 1444     Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 2050     Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 2695     Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 3405     Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 4135     Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 4806     Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 5540     Colorado/USA    6-5   215.0         9.0    26.0    Guard
# 6366     Colorado/USA    6-5   215.0         9.0    26.0    Guard
#
#      ROSTERSTATUS GAMES_PLAYED_CURRENT_SEASON_FLAG       TEAM_ID TEAM_NAME  \
# 801        Active                                Y  1.610613e+09      Nets
# 1444       Active                                Y  1.610613e+09      Nets
# 2050       Active                                Y  1.610613e+09      Nets
# 2695       Active                                Y  1.610613e+09      Nets
# 3405       Active                                Y  1.610613e+09      Nets
# 4135       Active                                Y  1.610613e+09      Nets
# 4806       Active                                Y  1.610613e+09      Nets
# 5540       Active                                Y  1.610613e+09      Nets
# 6366       Active                                Y  1.610613e+09      Nets
#
#      TEAM_ABBREVIATION TEAM_CODE TEAM_CITY         PLAYERCODE  FROM_YEAR  \
# 801                BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 1444               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 2050               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 2695               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 3405               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 4135               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 4806               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 5540               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
# 6366               BKN      nets  Brooklyn  spencer_dinwiddie     2014.0
#
#       TO_YEAR DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND  \
# 801    2023.0            Y        Y                 Y       2014           2
# 1444   2023.0            Y        Y                 Y       2014           2
# 2050   2023.0            Y        Y                 Y       2014           2
# 2695   2023.0            Y        Y                 Y       2014           2
# 3405   2023.0            Y        Y                 Y       2014           2
# 4135   2023.0            Y        Y                 Y       2014           2
# 4806   2023.0            Y        Y                 Y       2014           2
# 5540   2023.0            Y        Y                 Y       2014           2
# 6366   2023.0            Y        Y                 Y       2014           2
#
#      DRAFT_NUMBER GREATEST_75_FLAG
# 801            38                N
# 1444           38                N
# 2050           38                N
# 2695           38                N
# 3405           38                N
# 4135           38                N
# 4806           38                N
# 5540           38                N
# 6366           38                N

# %%
shooting[shooting['DISPLAY_FIRST_LAST'].isnull()]

# %% [markdown]
# A lot of names with accents did not merge from the player bios dataframe. This is still a small percentage of the total set so I will drop them, but the insights could end up being a little more American born driven than representative of the entire league.

# %%
shooting = shooting.dropna(subset=['DISPLAY_FIRST_LAST'])

# %% [markdown]
# Removed 449 rows where DISPLAY_FIRST_LAST was null, meaning I would have no data from the player bios dataframe on them.

# %%
shooting = shooting.dropna(subset=['POSITION', 'HEIGHT', 'WEIGHT'])

# %% [markdown]
# Removed 17 rows where position, height, or weight was null, meaning I would not have the important info I need from player bios.

# %%
shooting = shooting.drop(['JERSEY','TEAM_CODE', 'TEAM_CITY', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'DRAFT_NUMBER', 'DRAFT_ROUND'], axis=1)

# %% [markdown]
# Removed the remaining columns with null values that were non-numeric. I did not need those columns for the analysis I am planning.

# %%
shooting.isna().sum().sort_values(ascending=False)
# Out:
# 3P_FGast                            770
# Corner_3P%                          752
# 16-3P_FG%                           489
# 10-16_FG%                           419
# Corner_%3PA                         362
# 3P_FG%                              362
# 3-10_FG%                            208
# 0-3_FG%                             167
# 2P_FGast                            135
# 2P_FG%                               57
# 16-3P_FGA%                           25
# Dunks_%FGA                           25
# 3P_FGA%                              25
# 10-16_FGA%                           25
# 3-10_FGA%                            25
# 0-3_FGA%                             25
# 2P_FGA%                              25
# Dist.                                25
# FG%                                  25
# TEAM_ID                               0
# POSITION                              0
# SEASON_EXP                            0
# WEIGHT                                0
# ROSTERSTATUS                          0
# HEIGHT                                0
# LAST_AFFILIATION                      0
# GAMES_PLAYED_CURRENT_SEASON_FLAG      0
# Player                                0
# PLAYERCODE                            0
# FROM_YEAR                             0
# TO_YEAR                               0
# SCHOOL                                0
# DLEAGUE_FLAG                          0
# NBA_FLAG                              0
# GAMES_PLAYED_FLAG                     0
# DRAFT_YEAR                            0
# COUNTRY                               0
# Heaves_#                              0
# BIRTHDATE                             0
# Pos                                   0
# Age                                   0
# Tm                                    0
# G                                     0
# MP                                    0
# Dunks_#                               0
# Heaves_Att.                           0
# Year                                  0
# PLAYER_SLUG                           0
# PERSON_ID                             0
# FIRST_NAME                            0
# LAST_NAME                             0
# DISPLAY_FIRST_LAST                    0
# DISPLAY_LAST_COMMA_FIRST              0
# DISPLAY_FI_LAST                       0
# GREATEST_75_FLAG                      0
# dtype: int64

# %%
shooting.fillna(0, inplace=True)

# %% [markdown]
# The rest are numeric null values I replaced with 0. These were null likely because the players did not take shots from those distances. All null values have been cleaned.

# %%
shooting.to_csv('C:/Users/kevin/Downloads/shooting stats cleaned v2 2014-2023.csv', index=False)

# %% [markdown]
# ### Cleaning the Defense Data Set

# %%
defensive_df["Player"] = defensive_df["Player"].str.replace("*","", regex=False)
defensive_df["Player"] = defensive_df["Player"].str.replace("+","", regex=False)

# %%
defensive_df[defensive_df['Player'] == 'Zion Williamson']
# Out:
#                Player Pos Age   Tm   G    MP   PER   TS%  3PAr   FTr  ORB%  \
# 4618  Zion Williamson  PF  19  NOP  24   668  24.1  .616  .039  .494  10.1
# 5345  Zion Williamson  PF  20  NOP  61  2026  27.1  .649  .033  .510   8.9
# 6894  Zion Williamson  PF  22  NOP  29   956  25.2  .652  .041  .529   6.9
#
#       DRB%  TRB%  AST% STL% BLK%  TOV%  USG%  OWS  DWS   WS WS/48 OBPM  DBPM  \
# 4618  13.7  11.9  13.3  1.1  1.1  11.9  30.5  1.5  0.4  2.0  .141  3.5  -1.4
# 5345  14.7  11.8  19.7  1.3  1.8  11.6  29.8  7.1  1.6  8.7  .205  6.1  -0.3
# 6894  17.0  12.0  24.4  1.6  1.6  14.6  30.4  2.3  1.2  3.6  .180  4.8   1.0
#
#       BPM VORP  Year
# 4618  2.1  0.7  2020
# 5345  5.8  4.0  2021
# 6894  5.8  1.9  2023

# %%
defensive = pd.merge(defensive_df, player_bios, how='left', left_on='Player', right_on='DISPLAY_FIRST_LAST')

# %%
defensive = defensive[defensive['Player'] != 'Player']

# %%
defensive = defensive.groupby(["Player", "Year"]).apply(single_year)

# %%
defensive.index = defensive.index.droplevel()
defensive.index = defensive.index.droplevel()

# %%
defensive = defensive.dropna(subset=['DISPLAY_FIRST_LAST'])

# %% [markdown]
# Removed 390 rows where no data was transferred from player bios.

# %%
defensive = defensive.dropna(subset=['POSITION', 'HEIGHT', 'WEIGHT'])

# %%
defensive = defensive.drop(['JERSEY','TEAM_CODE', 'TEAM_CITY', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'DRAFT_NUMBER', 'DRAFT_ROUND'], axis=1)

# %% [markdown]
# Removed the columns I do not need again. 400 rows had null values for these.

# %%
defensive.isna().sum().sort_values(ascending=False)
# Out:
# 3PAr                                25
# FTr                                 25
# TS%                                 24
# TOV%                                21
# Player                               0
# DISPLAY_LAST_COMMA_FIRST             0
# DISPLAY_FI_LAST                      0
# PLAYER_SLUG                          0
# BIRTHDATE                            0
# SCHOOL                               0
# COUNTRY                              0
# LAST_AFFILIATION                     0
# HEIGHT                               0
# WEIGHT                               0
# SEASON_EXP                           0
# ROSTERSTATUS                         0
# POSITION                             0
# LAST_NAME                            0
# GAMES_PLAYED_CURRENT_SEASON_FLAG     0
# TEAM_ID                              0
# PLAYERCODE                           0
# FROM_YEAR                            0
# TO_YEAR                              0
# DLEAGUE_FLAG                         0
# NBA_FLAG                             0
# GAMES_PLAYED_FLAG                    0
# DRAFT_YEAR                           0
# DISPLAY_FIRST_LAST                   0
# Year                                 0
# FIRST_NAME                           0
# PERSON_ID                            0
# Age                                  0
# Tm                                   0
# G                                    0
# MP                                   0
# PER                                  0
# ORB%                                 0
# DRB%                                 0
# TRB%                                 0
# AST%                                 0
# STL%                                 0
# BLK%                                 0
# USG%                                 0
# OWS                                  0
# DWS                                  0
# WS                                   0
# WS/48                                0
# OBPM                                 0
# DBPM                                 0
# BPM                                  0
# VORP                                 0
# Pos                                  0
# GREATEST_75_FLAG                     0
# dtype: int64

# %% [markdown]
# Much less data that I have to fill in with zeroes here in this defensive data set. Realistically I could also drop these columns since these are not the columns I need for the data analysis, but since they are numeric values I might as well fill in with zeroes. It's also a very small number of rows that is affected at 20 out of 5000

# %%
defensive.fillna(0, inplace=True)

# %%
defensive.to_csv('C:/Users/kevin/Downloads/defensive stats cleaned v2 2014-2023.csv', index=False)
